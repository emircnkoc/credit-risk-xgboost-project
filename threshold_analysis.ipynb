# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

results = []

for t in [0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.5]:
    pred = (proba >= t).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()

    recall = tp / (tp + fn)   # default yakalama
    precision = tp / (tp + fp) if tp+fp>0 else 0
    approval_rate = (pred==0).mean()  # kredi verilen oran

    results.append([t, recall, precision, approval_rate])

df_thresh = pd.DataFrame(
    results,
    columns=["threshold","default_recall","default_precision","approval_rate"]
)

df_thresh
